# %% [markdown]
# ## **Construction Folder Path**

# %%
# competition name setting
if 'COMPETITION_NAME' not in locals():
    COMPETITION_NAME = '<competition name here>'

# %%
# Kaggle setting
if 'IS_COLAB' not in locals():
    INPUT_PATH = f'../input/{COMPETITION_NAME}'
    WORK_PATH = '../working'

# %% [markdown]
# ## **Main Process**

# %%
import os
import glob
import json
import warnings
import shutil
import logging
import joblib
import random
import datetime

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.auto import tqdm
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
