# %% [markdown]
# # check package version

# %% [markdown]
# ## Python version

# %%
# !python3 -V
# Out:
# Python 3.11.13

# %% [markdown]
# ## Package version

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
import torch
torch.__version__
# Out:
# '2.6.0+cu124'

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # ← 全部非表示

import tensorflow as tf
tf.__version__
# Out:
# '2.19.0'
